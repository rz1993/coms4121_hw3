# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import json

matches_df = pd.read_csv('train/matches_train.csv')
foursq_df = pd.read_json('train/foursquare_train.json')
locu_df = pd.read_json('train/locu_train.json')

# %%
def crossjoin(df1, df2, **kwargs):
    # Cross join the two org's data to form a dataframe of all possible pairs
    df1['_tmp'] = 1
    df2['_tmp'] = 1
    joined = pd.merge(foursq_df, locu_df, on=['_tmp'], **kwargs).drop('_tmp', axis=1)
    return joined

train_df = crossjoin(foursq_df, locu_df, suffixes=['_foursq', '_locu'])

matches_df.columns = ['id_locu', 'id_foursq']
matches_df['matched'] = 1
train_df = train_df.merge(matches_df, how='left', left_on=['id_locu', 'id_foursq'], right_on=['id_locu', 'id_foursq'])
train_df['matched'].fillna(0, inplace=True)
# Out:
#        country_foursq                 id_foursq  latitude_foursq  \
# 0       United States  4f328ea619836c91c7e3714a        40.794855
# 1       United States  4f328ea619836c91c7e3714a        40.794855
# 2       United States  4f328ea619836c91c7e3714a        40.794855
# 3       United States  4f328ea619836c91c7e3714a        40.794855
# 4       United States  4f328ea619836c91c7e3714a        40.794855
# 5       United States  4f328ea619836c91c7e3714a        40.794855
# 6       United States  4f328ea619836c91c7e3714a        40.794855
# 7       United States  4f328ea619836c91c7e3714a        40.794855
# 8       United States  4f328ea619836c91c7e3714a        40.794855
# 9       United States  4f328ea619836c91c7e3714a        40.794855
# 10      United States  4f328ea619836c91c7e3714a        40.794855
# 11      United States  4f328ea619836c91c7e3714a        40.794855
# 12      United States  4f328ea619836c91c7e3714a        40.794855
# 13      United States  4f328ea619836c91c7e3714a        40.794855
# 14      United States  4f328ea619836c91c7e3714a        40.794855
# 15      United States  4f328ea619836c91c7e3714a        40.794855
# 16      United States  4f328ea619836c91c7e3714a        40.794855
# 17      United States  4f328ea619836c91c7e3714a        40.794855
# 18      United States  4f328ea619836c91c7e3714a        40.794855
# 19      United States  4f328ea619836c91c7e3714a        40.794855
# 20      United States  4f328ea619836c91c7e3714a        40.794855
# 21      United States  4f328ea619836c91c7e3714a        40.794855
# 22      United States  4f328ea619836c91c7e3714a        40.794855
# 23      United States  4f328ea619836c91c7e3714a        40.794855
# 24      United States  4f328ea619836c91c7e3714a        40.794855
# 25      United States  4f328ea619836c91c7e3714a        40.794855
# 26      United States  4f328ea619836c91c7e3714a        40.794855
# 27      United States  4f328ea619836c91c7e3714a        40.794855
# 28      United States  4f328ea619836c91c7e3714a        40.794855
# 29      United States  4f328ea619836c91c7e3714a        40.794855
# ...               ...                       ...              ...
# 359970  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359971  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359972  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359973  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359974  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359975  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359976  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359977  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359978  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359979  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359980  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359981  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359982  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359983  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359984  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359985  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359986  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359987  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359988  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359989  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359990  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359991  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359992  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359993  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359994  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359995  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359996  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359997  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359998  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
# 359999  United States  4f7b04dee4b0dd0dafecd9cf        40.751789
#
#        locality_foursq  longitude_foursq  \
# 0             New York        -73.966069
# 1             New York        -73.966069
# 2             New York        -73.966069
# 3             New York        -73.966069
# 4             New York        -73.966069
# 5             New York        -73.966069
# 6             New York        -73.966069
# 7             New York        -73.966069
# 8             New York        -73.966069
# 9             New York        -73.966069
# 10            New York        -73.966069
# 11            New York        -73.966069
# 12            New York        -73.966069
# 13            New York        -73.966069
# 14            New York        -73.966069
# 15            New York        -73.966069
# 16            New York        -73.966069
# 17            New York        -73.966069
# 18            New York        -73.966069
# 19            New York        -73.966069
# 20            New York        -73.966069
# 21            New York        -73.966069
# 22            New York        -73.966069
# 23            New York        -73.966069
# 24            New York        -73.966069
# 25            New York        -73.966069
# 26            New York        -73.966069
# 27            New York        -73.966069
# 28            New York        -73.966069
# 29            New York        -73.966069
# ...                ...               ...
# 359970        New York        -74.006328
# 359971        New York        -74.006328
# 359972        New York        -74.006328
# 359973        New York        -74.006328
# 359974        New York        -74.006328
# 359975        New York        -74.006328
# 359976        New York        -74.006328
# 359977        New York        -74.006328
# 359978        New York        -74.006328
# 359979        New York        -74.006328
# 359980        New York        -74.006328
# 359981        New York        -74.006328
# 359982        New York        -74.006328
# 359983        New York        -74.006328
# 359984        New York        -74.006328
# 359985        New York        -74.006328
# 359986        New York        -74.006328
# 359987        New York        -74.006328
# 359988        New York        -74.006328
# 359989        New York        -74.006328
# 359990        New York        -74.006328
# 359991        New York        -74.006328
# 359992        New York        -74.006328
# 359993        New York        -74.006328
# 359994        New York        -74.006328
# 359995        New York        -74.006328
# 359996        New York        -74.006328
# 359997        New York        -74.006328
# 359998        New York        -74.006328
# 359999        New York        -74.006328
#
#                                             name_foursq    phone_foursq  \
# 0                              Chen Jin Diao Restaurant  (212) 678-4680
# 1                              Chen Jin Diao Restaurant  (212) 678-4680
# 2                              Chen Jin Diao Restaurant  (212) 678-4680
# 3                              Chen Jin Diao Restaurant  (212) 678-4680
# 4                              Chen Jin Diao Restaurant  (212) 678-4680
# 5                              Chen Jin Diao Restaurant  (212) 678-4680
# 6                              Chen Jin Diao Restaurant  (212) 678-4680
# 7                              Chen Jin Diao Restaurant  (212) 678-4680
# 8                              Chen Jin Diao Restaurant  (212) 678-4680
# 9                              Chen Jin Diao Restaurant  (212) 678-4680
# 10                             Chen Jin Diao Restaurant  (212) 678-4680
# 11                             Chen Jin Diao Restaurant  (212) 678-4680
# 12                             Chen Jin Diao Restaurant  (212) 678-4680
# 13                             Chen Jin Diao Restaurant  (212) 678-4680
# 14                             Chen Jin Diao Restaurant  (212) 678-4680
# 15                             Chen Jin Diao Restaurant  (212) 678-4680
# 16                             Chen Jin Diao Restaurant  (212) 678-4680
# 17                             Chen Jin Diao Restaurant  (212) 678-4680
# 18                             Chen Jin Diao Restaurant  (212) 678-4680
# 19                             Chen Jin Diao Restaurant  (212) 678-4680
# 20                             Chen Jin Diao Restaurant  (212) 678-4680
# 21                             Chen Jin Diao Restaurant  (212) 678-4680
# 22                             Chen Jin Diao Restaurant  (212) 678-4680
# 23                             Chen Jin Diao Restaurant  (212) 678-4680
# 24                             Chen Jin Diao Restaurant  (212) 678-4680
# 25                             Chen Jin Diao Restaurant  (212) 678-4680
# 26                             Chen Jin Diao Restaurant  (212) 678-4680
# 27                             Chen Jin Diao Restaurant  (212) 678-4680
# 28                             Chen Jin Diao Restaurant  (212) 678-4680
# 29                             Chen Jin Diao Restaurant  (212) 678-4680
# ...                                                 ...             ...
# 359970  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359971  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359972  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359973  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359974  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359975  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359976  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359977  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359978  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359979  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359980  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359981  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359982  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359983  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359984  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359985  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359986  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359987  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359988  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359989  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359990  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359991  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359992  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359993  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359994  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359995  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359996  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359997  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359998  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
# 359999  Van Leeuwen Truck - Coffee, Ice Cream, Pastries            None
#
#        postal_code_foursq region_foursq       street_address_foursq   ...    \
# 0                                    NY           800 Columbus Ave.   ...
# 1                                    NY           800 Columbus Ave.   ...
# 2                                    NY           800 Columbus Ave.   ...
# 3                                    NY           800 Columbus Ave.   ...
# 4                                    NY           800 Columbus Ave.   ...
# 5                                    NY           800 Columbus Ave.   ...
# 6                                    NY           800 Columbus Ave.   ...
# 7                                    NY           800 Columbus Ave.   ...
# 8                                    NY           800 Columbus Ave.   ...
# 9                                    NY           800 Columbus Ave.   ...
# 10                                   NY           800 Columbus Ave.   ...
# 11                                   NY           800 Columbus Ave.   ...
# 12                                   NY           800 Columbus Ave.   ...
# 13                                   NY           800 Columbus Ave.   ...
# 14                                   NY           800 Columbus Ave.   ...
# 15                                   NY           800 Columbus Ave.   ...
# 16                                   NY           800 Columbus Ave.   ...
# 17                                   NY           800 Columbus Ave.   ...
# 18                                   NY           800 Columbus Ave.   ...
# 19                                   NY           800 Columbus Ave.   ...
# 20                                   NY           800 Columbus Ave.   ...
# 21                                   NY           800 Columbus Ave.   ...
# 22                                   NY           800 Columbus Ave.   ...
# 23                                   NY           800 Columbus Ave.   ...
# 24                                   NY           800 Columbus Ave.   ...
# 25                                   NY           800 Columbus Ave.   ...
# 26                                   NY           800 Columbus Ave.   ...
# 27                                   NY           800 Columbus Ave.   ...
# 28                                   NY           800 Columbus Ave.   ...
# 29                                   NY           800 Columbus Ave.   ...
# ...                   ...           ...                         ...   ...
# 359970              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359971              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359972              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359973              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359974              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359975              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359976              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359977              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359978              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359979              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359980              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359981              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359982              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359983              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359984              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359985              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359986              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359987              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359988              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359989              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359990              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359991              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359992              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359993              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359994              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359995              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359996              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359997              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359998              10001            NY  601 W. 26th St., 2nd Floor   ...
# 359999              10001            NY  601 W. 26th St., 2nd Floor   ...
#
#        latitude_locu locality_locu longitude_locu  \
# 0          40.739822      New York     -73.985144
# 1          40.810765      New York     -73.952591
# 2          40.743580      New York     -73.986127
# 3          40.828820      New York     -73.949022
# 4          40.749936      New York     -73.983849
# 5          40.788494      New York     -73.943786
# 6          40.815148      New York     -73.939791
# 7          40.797416      New York     -73.937459
# 8          40.722915      New York     -73.998114
# 9          40.755041      New York     -73.977646
# 10         40.735754      New York     -73.989382
# 11         40.744880      New York     -73.981180
# 12         40.737783      New York     -73.989714
# 13         40.765521      New York     -73.980036
# 14         40.782643      New York     -73.951949
# 15         40.740689      New York     -73.981531
# 16         40.823280      New York     -73.950630
# 17         40.783318      New York     -73.947990
# 18         40.755335      New York     -73.983027
# 19         40.725055      New York     -73.979482
# 20         40.772840      New York     -73.952130
# 21         40.730358      New York     -73.983200
# 22         40.754023      New York     -73.995567
# 23         40.777606      New York     -73.945895
# 24         40.739794      New York     -73.979801
# 25         40.813799      New York     -73.955947
# 26         40.775431      New York     -73.956665
# 27         40.753399      New York     -73.970046
# 28         40.798420      New York     -73.938686
# 29         40.781909      New York     -73.951740
# ...              ...           ...            ...
# 359970     40.756223      New York     -73.980794
# 359971     40.720675      New York     -73.989879
# 359972     40.794487      New York     -73.939653
# 359973     40.761401      New York     -73.990043
# 359974     40.784615      New York     -73.979339
# 359975     40.758003      New York     -73.976393
# 359976     40.744872      New York     -73.983091
# 359977     40.762901      New York     -73.978302
# 359978     40.800449      New York     -73.946416
# 359979     40.740622      New York     -74.000653
# 359980     40.736879      New York     -73.993613
# 359981     40.719950      New York     -74.006260
# 359982     40.743335      New York     -74.004972
# 359983     40.714566      New York     -73.990208
# 359984     40.729018      New York     -73.978196
# 359985     40.732286      New York     -73.999279
# 359986     40.762478      New York     -73.968520
# 359987     40.774459      New York     -73.980538
# 359988     40.744650      New York     -73.992705
# 359989     40.706501      New York     -74.009900
# 359990     41.439910      New York     -74.414349
# 359991     40.739563      New York     -73.989826
# 359992     40.754109      New York     -73.993495
# 359993     40.803703      New York     -73.966980
# 359994     40.865882      New York     -73.927816
# 359995     40.756980      New York     -73.976240
# 359996     40.722960      New York     -74.011509
# 359997     40.711246      New York     -74.006359
# 359998     40.755873      New York     -73.969204
# 359999     40.740868      New York     -74.006921
#
#                               name_locu  phone_locu  postal_code_locu  \
# 0                Chipotle Mexican Grill  2126736904             10010
# 1                       Honey Salon Inc  2126630100             10026
# 2                               Palatte  6464763812             10016
# 3                 Best Taste Restaurant  2122815691             10031
# 4               Integra Hair System Inc  2125636786             10018
# 5         Halal JFK Fried Chicken Pizza  2123692514             10029
# 6                        Hong Kong Foid  2129265689             10037
# 7                           AAA Laundry  6466720202             10035
# 8                        Whiskey Friday                         10012
# 9                           Stauback Co  2127105250             10002
# 10                      T.G.I. Friday's  6465566381             10003
# 11                               Prespa  2128104335             10016
# 12                          ABC Kitchen  2124755829             10003
# 13                      57 Wellness Spa  2129563188             10019
# 14                        Melrose Place                         10021
# 15         Huang Laundry & Dry Cleaning  2124817698             10010
# 16                Marcell's Steak House  9173277549             10016
# 17          Famous Original Ray's Pizza  2123483955             10128
# 18                     crave sandwiches  2123987070             10036
# 19           Parliament of South Africa  2122135583             10009
# 20             Italian Village Pizzeria  2125355950             10075
# 21                        National Cafe  2124733700
# 22           Hudson Station Bar & Grill  2122444406             10001
# 23              India Garden Restaurant  8002966022
# 24                       Deli Superette
# 25                      Amsterdam Nails  2128655715             10027
# 26                      Allure Catering  2125850808             10028
# 27                         Jimmy's Gyro                         10017
# 28       El Kallejon Wine and Tapas Bar  9178539167             10035
# 29                       Buzz Publicity  2128600500             10128
# ...                                 ...         ...               ...
# 359970            Susana's Beauty Salon  2127680945             10036
# 359971                 Day Day Nail Inc  2123758088             10002
# 359972                  Wallah's Bodega                         10029
# 359973               Saigon 9 West Cafe  2127579813             10036
# 359974                    I Style Salon  2125019225             10024
# 359975           American Festival Cafe  2122466669             10020
# 359976                   P & P Brothers                         10022
# 359977                         Allegria  2129567755
# 359978                 Empire Corner II  2124105756             10029
# 359979                     The Grey Dog  2122292345             10011
# 359980                   Union Cleaners  2123379987             10011
# 359981          Myriad Restaurant Group  2122199500             10013
# 359982             Three Squares Studio  9178473384             10011
# 359983                     One Essex St                         10002
# 359984                           Subway  2122600245             10009
# 359985                 Babbo Ristorante  2127770303             10011
# 359986                     Vegan Picnic
# 359987                JoAnne Restaurant  9172617262             10023
# 359988                         Varietal  2126331800             10001
# 359989  Mangia Caterers and Restaurants  2124254040             10005
# 359990                             90 W  2127859090             10006
# 359991                              Eau  2123588647             10010
# 359992                             Pono  8663367666             10018
# 359993    Sing Yat Cleaners Corporation  2128656363             10025
# 359994               Maja's Tapas & Bar                         10034
# 359995         Au Croissant and Gourmet  2127506970
# 359996                    Mirzo's Pizza  2129417161
# 359997             THREAD Eyebrow Salon  2126089232             10038
# 359998                      Wild Ginger  2128298000             10022
# 359999                   Cafe Grayskull                         10014
#
#        region_locu          street_address_locu  \
# 0               NY            125 East 23rd St.
# 1               NY      174 Saint Nicholas Ave.
# 2               NY              66 Madison Ave.
# 3               NY                3609 Broadway
# 4               NY           11 W. 36th St. # 3
# 5               NY                1998 2nd Ave.
# 6               NY            527-09 Lenox Ave.
# 7               NY                2272 2nd Ave.
# 8               NY      Spring St. & Crosby St.
# 9               NY             366 Madison Ave.
# 10              NY         34 Union Square East
# 11              NY           184 Lexington Ave.
# 12              NY             35 East 18th St.
# 13              NY                200 W. 57 St.
# 14              NY                          Ues
# 15              NY            215 East 26th St.
# 16              NY           529 West 141st St.
# 17              NY                1827 2nd Ave.
# 18              NY    1120 Ave. Of The Americas
# 19              NY             333 East 8th St.
# 20              NY            1526 1st Ave. # 1
# 21              NY                 210 1st Ave.
# 22              NY                 440 9th Ave.
# 23              NY               1690 York Ave.
# 24              NY
# 25              NY          1349 Amsterdam Ave.
# 26              NY                1422 3rd Ave.
# 27              NY
# 28              NY               209e 117th St.
# 29              NY         1619 3rd Ave. # 6415
# ...            ...                          ...
# 359970          NY           55 W. 45th St. # 2
# 359971          NY                150 Allen St.
# 359972          NY
# 359973          NY            358 West 47th St.
# 359974          NY                2242 Broadway
# 359975          NY             20 West 50th St.
# 359976          NY           450 Park Ave. # 24
# 359977          NY    1350 Ave. Of The Americas
# 359978          NY                1415 5th Ave.
# 359979          NY            242 West 16th St.
# 359980          NY           20 W. 15th St. # A
# 359981          NY  249 West Broadway, Suite 2e
# 359982          NY            444 West 17th St.
# 359983          NY                  1 Essex St.
# 359984          NY              400 E. 14th St.
# 359985          NY              110 Waverly Pl.
# 359986          NY
# 359987          NY               70 W. 68th St.
# 359988          NY              138 W. 25th St.
# 359989          NY                  40 Wall St.
# 359990          NY            90 Washington St.
# 359991          NY                 913 Broadway
# 359992          NY  347 West 36th St. Suite 405
# 359993          NY                2808 Broadway
# 359994          NY              229 Dyckman St.
# 359995          NY             425 Madison Ave.
# 359996          NY                 264 West St.
# 359997          NY               140 Nassau St.
# 359998          NY            226 East 51st St.
# 359999          NY              416 W. 13th St.
#
#                                  website_locu matched
# 0                    http://www.chipotle.com/     NaN
# 1                                                 NaN
# 2                  http://www.palattenyc.com/     NaN
# 3                                                 NaN
# 4                 http://www.integrahair.com/     NaN
# 5            http://halaljfkchickenpizza.com/     NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                 http://www.tgifridays.com/     NaN
# 11                      http://prespanyc.net/     NaN
# 12               http://www.abckitchennyc.com     NaN
# 13                 http://57spa.blogspot.com/     NaN
# 14                                                NaN
# 15                                                NaN
# 16               http://marcell.hilliard.com/     NaN
# 17                     http://rayspizzany.com     NaN
# 18               http://crave-sandwiches.com/     NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22               http://www.hudsonstation.com     NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26             http://www.allurecatering.com/     NaN
# 27                                                NaN
# 28                                                NaN
# 29              http://www.buzzpublicity.com/     NaN
# ...                                       ...     ...
# 359970                                            NaN
# 359971                                            NaN
# 359972                                            NaN
# 359973                                            NaN
# 359974                                            NaN
# 359975                                            NaN
# 359976                                            NaN
# 359977                                            NaN
# 359978                                            NaN
# 359979             http://www.thegreydog.com/     NaN
# 359980                                            NaN
# 359981  http://www.myriadrestaurantgroup.com/     NaN
# 359982     http://www.threesquaresstudio.com/     NaN
# 359983                                            NaN
# 359984                 http://www.subway.com/     NaN
# 359985                    http://babbonyc.com     NaN
# 359986                                            NaN
# 359987                                            NaN
# 359988               http://www.varietal.com/     NaN
# 359989                                            NaN
# 359990             http://www.90wnewyork.com/     NaN
# 359991                                            NaN
# 359992      http://www.ponobyjoangoodman.com/     NaN
# 359993                                            NaN
# 359994                                            NaN
# 359995                                            NaN
# 359996                                            NaN
# 359997                http://threadsalon.com/     NaN
# 359998          http://www.wildgingernyc.net/     NaN
# 359999                                            NaN
#
# [360000 rows x 23 columns]

# %%
def prec_rec_f1(feature, df, mask):
    '''
    Utility function for evaluating the precision/recall/f1 of a
    feature matching function.
    Args:
        - feature - function that takes the dataframe as an input and
                    returns a numpy array of 1s and 0s binary labels
        - df      - the dataframe to evaluate the feature function on
        - mask    - the indices for positive labels
    Returns:
        - prec    - precision
        - rec     - recall
        - f1      - f1-score
    '''
    preds = feature(df)
    
    pos = preds.loc[mask]
    pos_preds = mask.loc[preds]
    prec = np.mean(pos_preds)
    rec = np.mean(pos)
    f1 = 2 / (1 / prec + 1 / rec)
    return prec, rec, f1

# %%
import re

y = train_df['matched'] == 1

stop_words = ['restaurant', 'inc', 'cafe', 'bakery', 'and', 'the', 'of']

def remove_words(s, words):
    return ' '.join([token for token in s.split() if s not in words])

def remove_punc(s):
    return re.sub('[.,&#\'()]', '', s)

def norm_name(name, default=''):
    # Normalize a location's name to get matches
    if not name:
        return default
    name = str(name).lower()
    name = remove_punc(name)
    name = remove_words(name, stop_words)
    return name

def unigrams(name):
    return norm_name(name).split()

def lat_long_match(df):
    # Latitude and longitudes differ in decimal places for foursquare and locu
    # Errors in coordinates and misisng values also reduce recall
    def norm_coord(coord):
        return round(coord, 4)
    return (df['latitude_foursq'].apply(norm_coord) == df['latitude_locu'].apply(norm_coord)) \
         & (df['longitude_foursq'].apply(norm_coord) == df['longitude_locu'].apply(norm_coord))

def phone_num_match(df):
    def norm_foursq_phone(p):
        if not p:
            return ''
        p = str(p).replace('(', '')
        p = p.replace(')', '')
        p = p.replace(' ', '')
        p = p.replace('-', '')
        return p
    
    norm_phone = df['phone_foursq'].apply(norm_foursq_phone)
    return norm_phone == df['phone_locu'].apply(lambda p: str(p))

def address_match(df):
    def norm(a, default='None'):
        if not a:
            return default
        a = str(a).lower()
        a = a.replace('east', 'e')
        a = a.replace('west', 'w')
        a = a.replace('square', 'sq')
        a = a.replace('.', '')
        a = a.replace(',', '')
        return a
    
    return df['street_address_foursq'].apply(lambda a: norm(a, default='None_foursq')) \
        == df['street_address_locu'].apply(lambda a: norm(a, default='None_locu'))

def name_match(df):
    return df['name_foursq'].apply(lambda a: norm_name(a, default='None_foursq')) \
        == df['name_locu'].apply(lambda a: norm_name(a, default='None_locu'))

# %%
print(prec_rec_f1(lat_long_match, train_df, mask))
print(prec_rec_f1(phone_num_match, train_df, mask))
print(prec_rec_f1(address_match, train_df, mask))
print(prec_rec_f1(name_match, train_df, mask))
# Out:
# (0.9571428571428572, 0.5583333333333333, 0.7052631578947369)
# (0.010081597933272424, 0.8888888888888888, 0.019937073611413975)
# (0.9632107023411371, 0.8, 0.8740515933232169)
# (0.7857142857142857, 0.7944444444444444, 0.7900552486187845)
# (0.956268221574344, 0.9111111111111111, 0.9331436699857751)

# %%
def errors(df, y_true, y_pred, cols, type='false_pos'):
    # Utility function for viewing classification errors
    if type == 'false_pos':
        return df.loc[~y_true & y_pred][cols]
    elif type == 'false_neg':
        return df.loc[y_true & ~y_pred][cols]

errors(train_df, y, name_match(train_df), ['name_foursq', 'name_locu'], type='false_neg').head(30)
# Out:
#                                name_foursq  \
# 290               Chen Jin Diao Restaurant
# 1683    Pearls: Chinese & Szechuan Cuisine
# 18352                           Via Brasil
# 20478          Foo Sing Chinese Restaurant
# 25454                           Littletown
# 26254                     Mamoun's Falafel
# 35892                       Dong Hai Grill
# 58315     71 Irving Place Coffee & Tea Bar
# 59166                       Bocca Di Bacco
# 64917                          Big Daddy's
# 70297                           Halel Cart
# 70942                        Enrico Ferezi
# 80058                         Tribeca Cafe
# 80565                         Ditch Plains
# 81343                       Bistro Vendome
# 89584                          Azul Bistro
# 91572                  El Capri Restaurant
# 96337                               Antika
# 97378       Tasty Hand-Pulled Noodles Inc.
# 98112                         Sushilicious
# 105170                   Barolo Ristorante
# 109996             Rubirosa at The Westway
# 117683              Mad River Bar & Grille
# 123247          Spring Social Running Club
# 127359                    Telio Restaurant
# 128675                        Crooked Tree
# 135340                            Buddakan
# 150568                        Fresh Bagels
# 167099                 Restaurant Triomphe
# 169567                       Café Integral
#
#                                      name_locu
# 290     Sally's West Indian Cuisine Restaurant
# 1683                                    Pearls
# 18352                      Brasilla Restaurant
# 20478                         Foo Sing Kitchen
# 25454                              Little Town
# 26254                                 Mamoun's
# 35892                      Dong Hai Restaurant
# 58315                          71 Irving Place
# 59166                 Bocca Di Bacco (Chelsea)
# 64917            Big Daddy's - Upper East Side
# 70297                               Exhale Spa
# 70942                        Enrico Ferezi Inc
# 80058                                TriBeCafe
# 80565              Ditch Plains - West Village
# 81343                     Bistro Vendome - NYC
# 89584                    Azul Argentine Bistro
# 91572                         Capri Restaurant
# 96337                          Antika Pizzeria
# 97378                Tasty Hand-Pulled Noodles
# 98112                            Sushi Licious
# 105170                                  Barolo
# 109996                             The Westway
# 117683                   Mad River Bar & Grill
# 123247                   Tsung Sun Social Club
# 127359                                   Telio
# 128675                        The Crooked Tree
# 135340                             Buddakan NY
# 150568                            Pick A Bagel
# 167099                                Triomphe
# 169567                           Cafe Integral

# %%
# Play around with approximate matching for names

def unigram_overlap(df):
    def overlap(row):
        grams1 = set(unigrams(row['name_foursq']))
        grams2 = set(unigrams(row['name_locu']))
        return len(grams1.intersection(grams2)) / float(min([len(grams1), len(grams2)]))
    return df.apply(overlap, axis=1)

overlaps = unigram_overlap(train_df)

def overlap_match(df):
    return overlaps > .5
    
def agg_feature(df):
    return lat_long_match(df) | address_match(df)

print(prec_rec_f1(overlap_match, train_df, mask))
print(prec_rec_f1(agg_feature, train_df, mask))
# Out:
# (0.7391304347826086, 0.8972222222222223, 0.8105395232120451)
# (0.956268221574344, 0.9111111111111111, 0.9331436699857751)
